# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Attrition Case Study.csv')
data.head()
# Out:
#    Attrition  Age     BusinessTravel  DailyRate              Department  \
# 0          1   41      Travel_Rarely       1102                   Sales
# 1          0   49  Travel_Frequently        279  Research & Development
# 2          1   37      Travel_Rarely       1373  Research & Development
# 3          0   33  Travel_Frequently       1392  Research & Development
# 4          0   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Attrition                   1470 non-null int64
# Age                         1470 non-null int64
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
sns.heatmap(data.isnull())

# %%
data.corr()
# Out:
#                           Attrition       Age  DailyRate  DistanceFromHome  \
# Attrition                  1.000000 -0.159205  -0.056652          0.077924
# Age                       -0.159205  1.000000   0.010661         -0.001686
# DailyRate                 -0.056652  0.010661   1.000000         -0.004985
# DistanceFromHome           0.077924 -0.001686  -0.004985          1.000000
# Education                 -0.031373  0.208034  -0.016806          0.021042
# EmployeeCount                   NaN       NaN        NaN               NaN
# EmployeeNumber            -0.010577 -0.010145  -0.050990          0.032916
# EnvironmentSatisfaction   -0.103369  0.010146   0.018355         -0.016075
# HourlyRate                -0.006846  0.024287   0.023381          0.031131
# JobInvolvement            -0.130016  0.029820   0.046135          0.008783
# JobLevel                  -0.169105  0.509604   0.002966          0.005303
# ...

# %%
sns.heatmap(data.corr())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Attrition                   1470 non-null int64
# Age                         1470 non-null int64
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
business_travel=pd.get_dummies(data['BusinessTravel'])
department=pd.get_dummies(data['Department'])
education_field=pd.get_dummies(data['EducationField'])
gender=pd.get_dummies(data['Gender'])
job_role=pd.get_dummies(data['JobRole'])
marital_status=pd.get_dummies(data['MaritalStatus'])
Over18=pd.get_dummies(data['Over18'])
over_time=pd.get_dummies(data['OverTime'])

# %%
data.drop(['JobRole','MaritalStatus','Over18','OverTime','BusinessTravel','Department','EducationField','Gender'],axis=1,inplace=True)

# %%
data1=pd.concat([data,business_travel,department,education_field,gender,job_role,marital_status,Over18,over_time],axis=1)
data1
# Out:
#       Attrition  Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0             1   41       1102                 1          2              1
# 1             0   49        279                 8          1              1
# 2             1   37       1373                 2          2              1
# 3             0   33       1392                 3          4              1
# 4             0   27        591                 2          1              1
# ...         ...  ...        ...               ...        ...            ...
# 1465          0   36        884                23          2              1
# 1466          0   39        613                 6          1              1
# 1467          0   27        155                 4          3              1
# 1468          0   49       1023                 2          3              1
# 1469          0   34        628                 8          3              1
#
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 56 columns):
# Attrition                    1470 non-null int64
# Age                          1470 non-null int64
# DailyRate                    1470 non-null int64
# DistanceFromHome             1470 non-null int64
# Education                    1470 non-null int64
# EmployeeCount                1470 non-null int64
# EmployeeNumber               1470 non-null int64
# EnvironmentSatisfaction      1470 non-null int64
# HourlyRate                   1470 non-null int64
# JobInvolvement               1470 non-null int64
# JobLevel                     1470 non-null int64
# JobSatisfaction              1470 non-null int64
# MonthlyIncome                1470 non-null int64
# MonthlyRate                  1470 non-null int64
# NumCompaniesWorked           1470 non-null int64
# PercentSalaryHike            1470 non-null int64
# PerformanceRating            1470 non-null int64
# ...

# %%
data.head()
# Out:
#    Attrition  Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0          1   41       1102                 1          2              1
# 1          0   49        279                 8          1              1
# 2          1   37       1373                 2          2              1
# 3          0   33       1392                 3          4              1
# 4          0   27        591                 2          1              1
#
#    EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  ...  \
# 0               1                        2          94               3  ...
# 1               2                        3          61               2  ...
# 2               4                        4          92               2  ...
# 3               5                        4          56               3  ...
# 4               7                        1          40               3  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
X = data.iloc[:,1:28]  #independent columns
y = data.iloc[:,0]    #target column i.e price range

# %%
X
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41       1102                 1          2              1
# 1      49        279                 8          1              1
# 2      37       1373                 2          2              1
# 3      33       1392                 3          4              1
# 4      27        591                 2          1              1
# ...   ...        ...               ...        ...            ...
# 1465   36        884                23          2              1
# 1466   39        613                 6          1              1
# 1467   27        155                 4          3              1
# 1468   49       1023                 2          3              1
# 1469   34        628                 8          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0                  1                        2          94               3
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int64

# %%
bestfeatures = SelectKBest(score_func=chi2, k=11)
fit = bestfeatures.fit(X,y)

# %%
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

# %%
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']

# %%
featureScores
# Out:
#                        Specs         Score
# 0                        Age  8.415528e+01
# 1                  DailyRate  9.565805e+02
# 2           DistanceFromHome  6.377214e+01
# 3                  Education  5.206422e-01
# 4              EmployeeCount  3.408412e-30
# 5             EmployeeNumber  5.812033e+01
# 6    EnvironmentSatisfaction  6.890594e+00
# 7                 HourlyRate  4.317791e-01
# 8             JobInvolvement  4.605616e+00
# 9                   JobLevel  2.493924e+01
# 10           JobSatisfaction  7.011947e+00
# 11             MonthlyIncome  1.279223e+05
# 12               MonthlyRate  1.196634e+03
# 13        NumCompaniesWorked  6.438654e+00
# 14         PercentSalaryHike  2.350269e-01
# 15         PerformanceRating  5.060644e-04
# 16  RelationshipSatisfaction  1.332333e+00
# 17             StandardHours  0.000000e+00
# 18          StockOptionLevel  2.526883e+01
# 19         TotalWorkingYears  2.307216e+02
# 20     TrainingTimesLastYear  3.085796e+00
# ...

# %%
print(featureScores.nlargest(10,'Score'))
# Out:
#                    Specs          Score
# 11         MonthlyIncome  127922.293694
# 12           MonthlyRate    1196.633553
# 1              DailyRate     956.580494
# 19     TotalWorkingYears     230.721618
# 22        YearsAtCompany     142.100054
# 23    YearsInCurrentRole     117.522596
# 25  YearsWithCurrManager     110.671534
# 0                    Age      84.155277
# 2       DistanceFromHome      63.772142
# 5         EmployeeNumber      58.120326

# %%
data1.head()
# Out:
#    Attrition  Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0          1   41       1102                 1          2              1
# 1          0   49        279                 8          1              1
# 2          1   37       1373                 2          2              1
# 3          0   33       1392                 3          4              1
# 4          0   27        591                 2          1              1
#
#    EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  ...  \
# 0               1                        2          94               3  ...
# 1               2                        3          61               2  ...
# 2               4                        4          92               2  ...
# 3               5                        4          56               3  ...
# 4               7                        1          40               3  ...
#
#    Research Director  Research Scientist  Sales Executive  \
# ...

# %%
X=data1.iloc[:,[11,12,1,19,22,23,25,0,2,5]]
y1=y

# %%
X
# Out:
#       JobSatisfaction  MonthlyIncome  Age  StockOptionLevel  WorkLifeBalance  \
# 0                   4           5993   41                 0                1
# 1                   2           5130   49                 1                3
# 2                   3           2090   37                 0                3
# 3                   3           2909   33                 0                3
# 4                   2           3468   27                 1                3
# ...               ...            ...  ...               ...              ...
# 1465                4           2571   36                 1                3
# 1466                1           9991   39                 1                3
# 1467                2           6142   27                 1                3
# 1468                2           5390   49                 0                2
# 1469                3           4404   34                 0                4
#
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y1, test_size=0.33, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier=Sequential()
# Out:
# WARNING:tensorflow:From C:\Users\hp\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
classifier.add(Dense(activation='relu',input_dim=10,units=8,kernel_initializer='uniform'))
# Out:
# WARNING:tensorflow:From C:\Users\hp\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\hp\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
classifier.add(Dense(activation="relu",  units=8, kernel_initializer="uniform")) # this are my input features

# %%
classifier.add(Dense(activation='relu',units=6,kernel_initializer='uniform')) # this are the my second hidden layer

# %%
classifier.add(Dense(activation='sigmoid',units=1,kernel_initializer='uniform')) # here i am using the sigmoid function beacuse
# its a classification problem

# %%
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\hp\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\hp\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\Users\hp\Anaconda3\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
classifier.fit(X_train, y_train, batch_size = 10, nb_epoch = 100)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   """Entry point for launching an IPython kernel.
# WARNING:tensorflow:From C:\Users\hp\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\hp\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From C:\Users\hp\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\hp\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# ...

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
cm=confusion_matrix(y_pred,y_test)
cm
# Out:
# array([[416,   0],
#        [  0,  70]], dtype=int64)

# %%
accuracy=accuracy_score(y_pred,y_test)
accuracy
# Out:
# 1.0

# %%
report=classification_report(y_pred,y_test)
report
# Out:
# '              precision    recall  f1-score   support\n\n       False       1.00      1.00      1.00       416\n        True       1.00      1.00      1.00        70\n\n    accuracy                           1.00       486\n   macro avg       1.00      1.00      1.00       486\nweighted avg       1.00      1.00      1.00       486\n'
